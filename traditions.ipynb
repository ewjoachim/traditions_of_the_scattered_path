  laoab rt nene stsa rtwe wt oi leb liotga nrsi oe awrlr ade. wi meuek oi iur oe ctge nena ifa hrkga (21) [22] twt ueni gehi utyt. nae dta oe mrue nrsi oeur wiua weoege oa oe est ueni oe rtwe ctfe oe paksewa intburse nrsi oe efet he oe crgi hrca oe yie figise nrsi oe fectweb hrca oe yawi faptse nrsi oe hepe hrca oe dtht fatpt grut nrsi oe cibe hrca oe utdali iase nrsi oe ktbew hrca oe ioise nrsi oe eltprw hrca oe mrue nena livpe yanr oe oafr nrsi oe avotft hrca oe lilr dtntkdt nrsi oe ctvork. medtk ce ekrot oe dabwese nrsi ytoa fidesise wrut leb crlrye wia leb crlrye dabwegt rda tla iyi cipa nrsi oeur wt dane sior neekmr sihrye he sawrut deme.

  nae esa meuek ytge oe ctgese nahame mahiga he ae wt tnt oa cesanase ntoagt hayr hrca stuahi wt hayr oe wi dane nrsi utmase. eur dta ytge oe lesi nrsi laurrse yarhe yrena twt gaet htlr wt oi mahiga.
"""

# %%
def pairs(word: str, joiner="") -> t.Iterable[str]:
    """Extracts digrams (pairs of consecutive letters) from a word"""
    it1, it2 = iter(word), iter(word)
    next(it2)
    return list(joiner.join(e) for e in zip(it1, it2))

# %%
def words(text: str):
    """splits a text into words, cleening it too (probably naive...)"""
    text = text.upper()
    text = "".join(c if c in string.ascii_uppercase else " " for c in text)
    return text.split()

# %%
from collections import Counter
def most_frequent_digrams(digrams: t.Iterable[str], freq=True) -> t.Dict[str, float]:
    """Returns frequency (0<x<1) of each digram"""
    c = Counter(digrams)
    common = dict(c.most_common())
    if not freq:
        return common
    
    total = sum(c.values())
    return {k: v/total for k, v in common.items()}

# %%
# I'm assuming the style of Traditions matches the style of the bible, as a seemingly sacred text
with open("genesis.txt") as f:
    bible = words(f.read())

# %%
def _surroundings(word, words, n=1):
    for i, w in enumerate(words):
        if w == word:
            yield words[i-n:i+n+1]
            
def surroundings(*a):
    return list(_surroundings(*a))

# %%
most_frequent_digrams(dg for w in words(cipher) for dg in pairs(w))
# Out:
# {'OE': 0.03503010399562124,
#  'SE': 0.020434227330779056,
#  'SI': 0.018700966976829044,
#  'RS': 0.017697500456121146,
#  'LE': 0.01760627622696588,
#  'NR': 0.016511585477102717,
#  'NE': 0.01578179164386061,
#  'WT': 0.015508118956394819,
#  'DT': 0.014960773581463237,
#  'EN': 0.014687100893997445,
#  'DE': 0.0140485312899106,
#  'NA': 0.013592410144134282,
#  'ES': 0.012953840540047437,
#  'HE': 0.012315270935960592,
#  'ME': 0.012315270935960592,
#  'OI': 0.011129355956942163,
#  'NI': 0.0110381317277869,
#  'UE': 0.010490786352855318,
#  'UR': 0.010308337894544791,
#  'FI': 0.010217113665389528,
#  'FT': 0.010034665207079,
#  'EB': 0.009943440977923736,
#  'OA': 0.009852216748768473,
#  'HA': 0.009669768290457946,
#  'YR': 0.009396095602992155,
#  'CA': 0.008939974457215836,
#  'WE': 0.00875752599890531,
#  'HI': 0.008575077540594781,
#  'HR': 0.008392629082284254,
#  'CT': 0.008392629082284254,
#  'YT': 0.008392629082284254,
#  'SA': 0.008301404853128991,
# ...

# %%
most_frequent_digrams(dg for w in bible for dg in pairs(w))
# Out:
# {'TH': 0.05882095228081244,
#  'HE': 0.05257347142631828,
#  'AN': 0.043592170057655574,
#  'ND': 0.038439969857876385,
#  'ER': 0.020617563044354484,
#  'HA': 0.017279147608783275,
#  'RE': 0.016928657799274487,
#  'IN': 0.01567565673028057,
#  'HI': 0.01557050978742793,
#  'TO': 0.013520144401801517,
#  'AT': 0.013029458668489214,
#  'OF': 0.012696493349455865,
#  'IS': 0.012346003539947076,
#  'EN': 0.012118185163766363,
#  'ED': 0.011750170863782135,
#  'SE': 0.011355869828084748,
#  'NT': 0.011215673904281234,
#  'OU': 0.011180624923330355,
#  'AR': 0.010479645304312777,
#  'OR': 0.010304400399558383,
#  'ME': 0.009533322818639047,
#  'VE': 0.009366840159122373,
#  'ON': 0.009349315668646933,
#  'LL': 0.009244168725794297,
#  'EA': 0.008797294218670593,
#  'SA': 0.008648336049629357,
#  'AL': 0.008499377880588122,
#  'BE': 0.008332895221071447,
#  'IT': 0.00823651052345653,
#  'ES': 0.008140125825841614,
#  'UN': 0.008017454392513538,
#  'AM': 0.007815922752045984,
# ...

# %%
cipher_words = words(cipher)
nl = "\n"
for k, v in collections.Counter(cipher_words).most_common():
    if v == 1:
        break
    print(f"{k}: {v}")
    for k, v in collections.Counter(' '.join(e) for e in surroundings(k, cipher_words)).most_common():
        print(f"    {v} - {k}")
# Out:
# OE: 334
#     5 - NRSI OE AWRLR
#     3 - NRSI OE ADE
#     3 - NRSI OE MEGTLR
#     3 - RPT OE YIE
#     3 - NRSI OE GRUT
#     3 - LTNI OE NRTFT
#     2 - NRSI OE FTCA
#     2 - NRSI OE ABAMAB
#     2 - NRSI OE DTLER
#     2 - EA OE GTWT
#     2 - NRSI OE FECTWEB
#     2 - LEFI OE HEPE
#     2 - NRSI OE HEPE
#     2 - NRSI OE FAFIDA
#     2 - UENI OE HAAFA
#     2 - NRSI OE KTBEW
#     2 - RPT OE FTCA
#     2 - WT OE GEMI
#     2 - WT OE PEOT
#     2 - NRSI OE ELTPRW
#     2 - WT OE CTVORK
#     2 - NRSI OE CTVORK
#     1 -
#     1 - LACISTV OE GRDRPE
#     1 - LRYRPE OE WIA
#     1 - NAWALA OE PTLT
#     1 - YTLAT OE AWRLR
#     1 - RT OE YTLILEOI
#     1 - INTBURSE OE HTWTST
#     1 - HE OE DRE
#     1 - UENI OE OANT
#     1 - HE OE DTLER
#     1 - UAGR OE HTLR
#     1 - UENI OE RYTOE
#     1 - DTA OE DRESE
#     1 - LEFI OE YTLILESE
#     1 - ASAYI OE HTWTST
#     1 - HIE OE CAKFRSE
#     1 - NIFTUR OE CRGI
#     1 - MIIMR OE DRMRMTSE
#     1 - MEDTK OE CIHEE
# ...

# %%
most_frequent_digrams(pairs(words(cipher), joiner=" "), freq=False)
# Out:
# {'NRSI OE': 61,
#  'UENI OE': 21,
#  'RPT OE': 14,
#  'RT OE': 12,
#  'WT OE': 12,
#  'OE KTBEW': 12,
#  'UAGR OE': 11,
#  'OE FTCA': 10,
#  'NRSI LEB': 9,
#  'WT OI': 9,
#  'OE CTVORK': 9,
#  'OE AWRLR': 8,
#  'AWRLR ADE': 8,
#  'OE ADE': 8,
#  'HRCA OE': 8,
#  'OE HEPE': 8,
#  'NENE FTCA': 7,
#  'NRSI YTOA': 7,
#  'DTA OE': 7,
#  'OE FECTWEB': 7,
#  'OA OE': 7,
#  'LEFI OE': 6,
#  'ESA MTUI': 6,
#  'OE MEGTLR': 6,
#  'RT NENE': 6,
#  'OE ELTPRW': 6,
#  'EUR RT': 5,
#  'HE OE': 5,
#  'ADE EUR': 5,
#  'OE YIE': 5,
#  'NAE OE': 5,
#  'OE GRUT': 5,
#  'YTOA DELACT': 5,
#  'OE DAYRWT': 5,
#  'FTCA RT': 4,
#  'NENA LEFI': 4,
#  'IUR UENI': 4,
#  'EUR DTA': 4,
#  'EA OE': 4,
#  'AE NENA': 4,
#  'MEGTLR FTCA': 4,
#  'YIE FIGISE': 4,
#  'OE ADESE': 4,
#  'WT ESA': 4,
#  'OE PEOT': 4,
#  'NRSI NENE': 4,
#  'OE NRTFT': 4,
#  'FTCTMI OE': 4,
#  'DTCR OE': 4,
#  'DAYRWT HRDRSE': 4,
#  'YTGE OE': 4,
#  'NRSI OEUR': 4,
#  'ADE RT': 3,
#  'RT LEB': 3,
#  'HAYR YTGE': 3,
#  'RT NIFTUR': 3,
# ...

# %%
most_frequent_digrams(pairs(bible, joiner=" "), freq=False)
# Out:
# {'OF THE': 379,
#  'AND THE': 362,
#  'AND HE': 338,
#  'IN THE': 297,
#  'SAID UNTO': 179,
#  'THE LORD': 164,
#  'THE LAND': 158,
#  'AND THEY': 144,
#  'HE SAID': 115,
#  'THE EARTH': 114,
#  'HIM AND': 114,
#  'ALL THE': 110,
#  'I WILL': 105,
#  'LAND OF': 104,
#  'AND SAID': 97,
#  'UNTO HIM': 91,
#  'AND IT': 89,
#  'ME AND': 87,
#  'AND HIS': 84,
#  'AND I': 83,
#  'AND SHE': 82,
#  'CAME TO': 80,
#  'SHALL BE': 77,
#  'SONS OF': 77,
#  'TO PASS': 75,
#  'OF HIS': 74,
#  'THE SONS': 74,
#  'UPON THE': 70,
#  'HIS FATHER': 69,
#  'THEE AND': 69,
#  'I HAVE': 67,
#  'AND GOD': 66,
#  'UNTO THE': 66,
#  'AND JACOB': 66,
#  'IT CAME': 63,
#  'EARTH AND': 62,
#  'AND ALL': 62,
#  'OUT OF': 62,
#  'TO THE': 62,
#  'AND JOSEPH': 60,
#  'YEARS AND': 58,
#  'THEM AND': 58,
#  'SON AND': 53,
#  'OF MY': 52,
#  'UNTO HIS': 51,
#  'WITH HIM': 51,
#  'THOU SHALT': 50,
#  'THAT HE': 49,
#  'HE HAD': 49,
#  'HIS BRETHREN': 47,
#  'OF EGYPT': 47,
#  'FATHER AND': 46,
#  'FROM THE': 45,
# ...
